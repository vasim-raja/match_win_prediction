# %%
import pandas as pd

# %%
pd.set_option('display.max_columns', None)

matches = pd.read_csv("/content/drive/MyDrive/my projects/match win prediction/matches.csv",index_col=0)

# %%
matches.head()
# Out:
#          date   time            comp        round  day venue result   gf   ga  \
# 0  2022-08-05  20:00  Premier League  Matchweek 1  Fri  Away      W  2.0  0.0
# 1  2022-08-13  15:00  Premier League  Matchweek 2  Sat  Home      W  4.0  2.0
# 2  2022-08-20  17:30  Premier League  Matchweek 3  Sat  Away      W  3.0  0.0
# 3  2022-08-27  17:30  Premier League  Matchweek 4  Sat  Home      W  2.0  1.0
# 4  2022-08-31  19:30  Premier League  Matchweek 5  Wed  Home      W  2.0  1.0
#
#          opponent   xg  xga  poss  attendance          captain formation  \
# 0  Crystal Palace  1.0  0.9  43.0     25286.0  Martin Ødegaard   4-2-3-1
# 1  Leicester City  2.6  0.6  51.0     60033.0  Martin Ødegaard   4-2-3-1
# 2     Bournemouth  1.8  0.3  59.0     10423.0  Martin Ødegaard   4-2-3-1
# 3          Fulham  2.4  1.1  71.0     60164.0  Martin Ødegaard   4-2-3-1
# 4     Aston Villa  2.7  0.2  59.0     60012.0  Martin Ødegaard   4-2-3-1
#
# ...

# %%
matches.shape
# Out:
# (1640, 27)

# %%
matches.team.value_counts()
# Out:
# Arsenal                     82
# Southampton                 82
# Leicester City              82
# West Ham United             82
# Aston Villa                 82
# Everton                     82
# Crystal Palace              82
# Wolverhampton Wanderers     82
# Manchester City             82
# Newcastle United            82
# Leeds United                82
# Liverpool                   82
# Chelsea                     82
# Manchester United           82
# Brighton and Hove Albion    82
# Tottenham Hotspur           82
# Burnley                     76
# Fulham                      44
# Brentford                   44
# Norwich City                38
# West Bromwich Albion        38
# Sheffield United            38
# Watford                     38
# Nottingham Forest            6
# Bournemouth                  6
# Name: team, dtype: int64

# %%
matches["round"].value_counts()
# Out:
# Matchweek 1     60
# Matchweek 3     60
# Matchweek 4     60
# Matchweek 5     60
# Matchweek 6     60
# Matchweek 2     60
# Matchweek 31    40
# Matchweek 25    40
# Matchweek 26    40
# Matchweek 27    40
# Matchweek 28    40
# Matchweek 29    40
# Matchweek 34    40
# Matchweek 32    40
# Matchweek 30    40
# Matchweek 23    40
# Matchweek 35    40
# Matchweek 36    40
# Matchweek 33    40
# Matchweek 37    40
# Matchweek 24    40
# Matchweek 20    40
# Matchweek 22    40
# Matchweek 21    40
# Matchweek 19    40
# Matchweek 18    40
# Matchweek 17    40
# Matchweek 16    40
# Matchweek 15    40
# Matchweek 14    40
# Matchweek 13    40
# Matchweek 12    40
# Matchweek 11    40
# Matchweek 10    40
# Matchweek 9     40
# Matchweek 8     40
# Matchweek 7     40
# Matchweek 38    40
# Name: round, dtype: int64

# %%
#preprocessing

# %%
matches.dtypes
# Out:
# date             object
# time             object
# comp             object
# round            object
# day              object
# venue            object
# result           object
# gf              float64
# ga              float64
# opponent         object
# xg              float64
# xga             float64
# poss            float64
# attendance      float64
# captain          object
# formation        object
# referee          object
# match report     object
# notes           float64
# sh              float64
# sot             float64
# dist            float64
# fk              float64
# pk              float64
# pkatt           float64
# season            int64
# team             object
# dtype: object

# %%
matches["date"] = pd.to_datetime(matches["date"])

# %%
matches.dtypes
# Out:
# date            datetime64[ns]
# time                    object
# comp                    object
# round                   object
# day                     object
# venue                   object
# result                  object
# gf                     float64
# ga                     float64
# opponent                object
# xg                     float64
# xga                    float64
# poss                   float64
# attendance             float64
# captain                 object
# formation               object
# referee                 object
# match report            object
# notes                  float64
# sh                     float64
# sot                    float64
# dist                   float64
# fk                     float64
# pk                     float64
# pkatt                  float64
# season                   int64
# team                    object
# dtype: object

# %%
#predictors

# %%
matches["venue_code"] = matches["venue"].astype("category").cat.codes #converting home/away into codes

# %%
matches.head()
# Out:
#         date   time            comp        round  day venue result   gf   ga  \
# 0 2022-08-05  20:00  Premier League  Matchweek 1  Fri  Away      W  2.0  0.0
# 1 2022-08-13  15:00  Premier League  Matchweek 2  Sat  Home      W  4.0  2.0
# 2 2022-08-20  17:30  Premier League  Matchweek 3  Sat  Away      W  3.0  0.0
# 3 2022-08-27  17:30  Premier League  Matchweek 4  Sat  Home      W  2.0  1.0
# 4 2022-08-31  19:30  Premier League  Matchweek 5  Wed  Home      W  2.0  1.0
#
#          opponent   xg  xga  poss  attendance          captain formation  \
# 0  Crystal Palace  1.0  0.9  43.0     25286.0  Martin Ødegaard   4-2-3-1
# 1  Leicester City  2.6  0.6  51.0     60033.0  Martin Ødegaard   4-2-3-1
# 2     Bournemouth  1.8  0.3  59.0     10423.0  Martin Ødegaard   4-2-3-1
# 3          Fulham  2.4  1.1  71.0     60164.0  Martin Ødegaard   4-2-3-1
# 4     Aston Villa  2.7  0.2  59.0     60012.0  Martin Ødegaard   4-2-3-1
#
# ...

# %%
matches["opponent_code"] = matches["opponent"].astype("category").cat.codes

# %%
matches.head()
# Out:
#         date   time            comp        round  day venue result   gf   ga  \
# 0 2022-08-05  20:00  Premier League  Matchweek 1  Fri  Away      W  2.0  0.0
# 1 2022-08-13  15:00  Premier League  Matchweek 2  Sat  Home      W  4.0  2.0
# 2 2022-08-20  17:30  Premier League  Matchweek 3  Sat  Away      W  3.0  0.0
# 3 2022-08-27  17:30  Premier League  Matchweek 4  Sat  Home      W  2.0  1.0
# 4 2022-08-31  19:30  Premier League  Matchweek 5  Wed  Home      W  2.0  1.0
#
#          opponent   xg  xga  poss  attendance          captain formation  \
# 0  Crystal Palace  1.0  0.9  43.0     25286.0  Martin Ødegaard   4-2-3-1
# 1  Leicester City  2.6  0.6  51.0     60033.0  Martin Ødegaard   4-2-3-1
# 2     Bournemouth  1.8  0.3  59.0     10423.0  Martin Ødegaard   4-2-3-1
# 3          Fulham  2.4  1.1  71.0     60164.0  Martin Ødegaard   4-2-3-1
# 4     Aston Villa  2.7  0.2  59.0     60012.0  Martin Ødegaard   4-2-3-1
#
# ...

# %%
matches["hour"] = matches["time"].str.replace(":.+","",regex="True").astype("int")

# %%
matches["day_code"] = matches["date"].dt.dayofweek

# %%
matches["target"] = (matches.result == "W").astype("int")

# %%
matches.head(10)
# Out:
#         date   time            comp        round  day venue result   gf   ga  \
# 0 2022-08-05  20:00  Premier League  Matchweek 1  Fri  Away      W  2.0  0.0
# 1 2022-08-13  15:00  Premier League  Matchweek 2  Sat  Home      W  4.0  2.0
# 2 2022-08-20  17:30  Premier League  Matchweek 3  Sat  Away      W  3.0  0.0
# 3 2022-08-27  17:30  Premier League  Matchweek 4  Sat  Home      W  2.0  1.0
# 4 2022-08-31  19:30  Premier League  Matchweek 5  Wed  Home      W  2.0  1.0
# 5 2022-09-04  16:30  Premier League  Matchweek 6  Sun  Away      L  1.0  3.0
# 1 2022-08-07  16:30  Premier League  Matchweek 1  Sun  Away      W  2.0  0.0
# 2 2022-08-13  15:00  Premier League  Matchweek 2  Sat  Home      W  4.0  0.0
# 3 2022-08-21  16:30  Premier League  Matchweek 3  Sun  Away      D  3.0  3.0
# 4 2022-08-27  15:00  Premier League  Matchweek 4  Sat  Home      W  4.0  2.0
#
#          opponent   xg  xga  poss  attendance          captain formation  \
# ...

# %%
# sample model

# %%
from sklearn.ensemble import RandomForestClassifier

# %%
rf = RandomForestClassifier(n_estimators=50, min_samples_split=10, random_state=1)

# %%
train = matches[matches["date"] < '2022-08-01']

# %%
test = matches[matches["date"] > '2022-08-01']

# %%
len(train)
# Out:
# 1520

# %%
len(test)
# Out:
# 120

# %%
predictors = ["venue_code", "opponent_code", "hour", "day_code"]

# %%
rf.fit(train[predictors], train["target"])
# Out:
# RandomForestClassifier(min_samples_split=10, n_estimators=50, random_state=1)

# %%
preds = rf.predict(test[predictors])

# %%
from sklearn.metrics import accuracy_score
error = accuracy_score(test["target"], preds)
error
# Out:
# 0.625

# %%
combined = pd.DataFrame(dict(actual=test["target"], predicted=preds))

# %%
pd.crosstab(index=combined["actual"], columns=combined["predicted"])
# Out:
# predicted   0   1
# actual
# 0          60  18
# 1          27  15

# %%
from sklearn.metrics import precision_score

precision_score(test["target"], preds)
# Out:
# 0.45454545454545453

# %%
  #so the results are bad.

# %%
#improving precision with rolling avg. we will groupby the table according to team. then
# calculate the stats like sot,ts,fk,pk.... take the avg of previous rows.

# %%
grouped_matches = matches.groupby("team")

# %%
group = grouped_matches.get_group("Manchester City").sort_values("date")

# %%
def rolling_averages(group, cols, new_cols):
    group = group.sort_values("date")
    rolling_stats = group[cols].rolling(3, closed='left').mean()   #to leave the current row stats
    group[new_cols] = rolling_stats
    group = group.dropna(subset=new_cols)
    return group

# %%
cols = ["gf", "ga", "sh", "sot", "dist", "fk", "pk", "pkatt"]
new_cols = [f"{c}_rolling" for c in cols]

# %%
rolling_averages(group, cols, new_cols)
# Out:
#          date   time            comp        round  day venue result   gf   ga  \
# 5  2020-10-17  17:30  Premier League  Matchweek 5  Sat  Home      W  1.0  0.0
# 7  2020-10-24  12:30  Premier League  Matchweek 6  Sat  Away      D  1.0  1.0
# 9  2020-10-31  12:30  Premier League  Matchweek 7  Sat  Away      W  1.0  0.0
# 11 2020-11-08  16:30  Premier League  Matchweek 8  Sun  Home      D  1.0  1.0
# 12 2020-11-21  17:30  Premier League  Matchweek 9  Sat  Away      L  0.0  2.0
# ..        ...    ...             ...          ...  ...   ...    ...  ...  ...
# 2  2022-08-13  15:00  Premier League  Matchweek 2  Sat  Home      W  4.0  0.0
# 3  2022-08-21  16:30  Premier League  Matchweek 3  Sun  Away      D  3.0  3.0
# 4  2022-08-27  15:00  Premier League  Matchweek 4  Sat  Home      W  4.0  2.0
# 5  2022-08-31  19:30  Premier League  Matchweek 5  Wed  Home      W  6.0  0.0
# 6  2022-09-03  17:30  Premier League  Matchweek 6  Sat  Away      D  1.0  1.0
#
# ...

# %%
matches_rolling = matches.groupby("team").apply(lambda x: rolling_averages(x, cols, new_cols))
matches_rolling
# Out:
#                                  date   time            comp        round  \
# team
# Arsenal                 6  2020-10-04  14:00  Premier League  Matchweek 4
#                         7  2020-10-17  17:30  Premier League  Matchweek 5
#                         9  2020-10-25  19:15  Premier League  Matchweek 6
#                         11 2020-11-01  16:30  Premier League  Matchweek 7
#                         13 2020-11-08  19:15  Premier League  Matchweek 8
# ...                               ...    ...             ...          ...
# Wolverhampton Wanderers 1  2022-08-13  15:00  Premier League  Matchweek 2
#                         2  2022-08-20  12:30  Premier League  Matchweek 3
#                         4  2022-08-28  14:00  Premier League  Matchweek 4
#                         5  2022-08-31  19:30  Premier League  Matchweek 5
#                         6  2022-09-03  15:00  Premier League  Matchweek 6
#
# ...

# %%
matches_rolling = matches_rolling.droplevel('team')

# %%
matches_rolling
# Out:
#          date   time            comp        round  day venue result   gf   ga  \
# 6  2020-10-04  14:00  Premier League  Matchweek 4  Sun  Home      W  2.0  1.0
# 7  2020-10-17  17:30  Premier League  Matchweek 5  Sat  Away      L  0.0  1.0
# 9  2020-10-25  19:15  Premier League  Matchweek 6  Sun  Home      L  0.0  1.0
# 11 2020-11-01  16:30  Premier League  Matchweek 7  Sun  Away      W  1.0  0.0
# 13 2020-11-08  19:15  Premier League  Matchweek 8  Sun  Home      L  0.0  3.0
# ..        ...    ...             ...          ...  ...   ...    ...  ...  ...
# 1  2022-08-13  15:00  Premier League  Matchweek 2  Sat  Home      D  0.0  0.0
# 2  2022-08-20  12:30  Premier League  Matchweek 3  Sat  Away      L  0.0  1.0
# 4  2022-08-28  14:00  Premier League  Matchweek 4  Sun  Home      D  1.0  1.0
# 5  2022-08-31  19:30  Premier League  Matchweek 5  Wed  Away      D  0.0  0.0
# 6  2022-09-03  15:00  Premier League  Matchweek 6  Sat  Home      W  1.0  0.0
#
# ...

# %%
matches_rolling.index = range(matches_rolling.shape[0])

# %%
def make_predictions(data, predictors):
    train = data[data["date"] < '2022-05-01']
    test = data[data["date"] > '2022-05-01']
    rf.fit(train[predictors], train["target"])
    preds = rf.predict(test[predictors])
    combined = pd.DataFrame(dict(actual=test["target"], predicted=preds), index=test.index)
    error = precision_score(test["target"], preds)
    return combined, error

# %%
combined, error = make_predictions(matches_rolling, predictors + new_cols)

# %%
error
# Out:
# 0.5306122448979592

# %%
combined = combined.merge(matches_rolling[["date", "team", "opponent", "result"]], left_index=True, right_index=True)

# %%
combined.head(10)
# Out:
#     actual  predicted       date     team        opponent result
# 69       1          0 2022-05-08  Arsenal    Leeds United      W
# 70       0          0 2022-05-12  Arsenal       Tottenham      L
# 71       0          0 2022-05-16  Arsenal   Newcastle Utd      L
# 72       1          0 2022-05-22  Arsenal         Everton      W
# 73       1          0 2022-08-05  Arsenal  Crystal Palace      W
# 74       1          0 2022-08-13  Arsenal  Leicester City      W
# 75       1          1 2022-08-20  Arsenal     Bournemouth      W
# 76       1          0 2022-08-27  Arsenal          Fulham      W
# 77       1          1 2022-08-31  Arsenal     Aston Villa      W
# 78       0          0 2022-09-04  Arsenal  Manchester Utd      L

# %%
class MissingDict(dict):
    __missing__ = lambda self, key: key

map_values = {"Brighton and Hove Albion": "Brighton", "Manchester United": "Manchester Utd", 
              "Newcastle United": "Newcastle Utd", "Tottenham Hotspur": "Tottenham", "West Ham United": "West Ham",
              "Wolverhampton Wanderers": "Wolves"} 
mapping = MissingDict(**map_values)

# %%
combined["new_team"] = combined["team"].map(mapping)

# %%
merged = combined.merge(combined, left_on=["date", "new_team"], right_on=["date", "opponent"])

# %%
merged
# Out:
#      actual_x  predicted_x       date                   team_x  \
# 0           1            0 2022-05-08                  Arsenal
# 1           0            0 2022-05-12                  Arsenal
# 2           0            0 2022-05-16                  Arsenal
# 3           1            0 2022-05-22                  Arsenal
# 4           1            0 2022-08-05                  Arsenal
# ..        ...          ...        ...                      ...
# 178         0            0 2022-08-13  Wolverhampton Wanderers
# 179         0            0 2022-08-20  Wolverhampton Wanderers
# 180         0            0 2022-08-28  Wolverhampton Wanderers
# 181         0            0 2022-08-31  Wolverhampton Wanderers
# 182         1            1 2022-09-03  Wolverhampton Wanderers
#
#          opponent_x result_x new_team_x  actual_y  predicted_y  \
# 0      Leeds United        W    Arsenal         0            0
# 1         Tottenham        L    Arsenal         1            0
# ...

# %%
merged[(merged["predicted_x"] == 1) & (merged["predicted_y"] ==0)]["actual_x"].value_counts()
# Out:
# 1    22
# 0    19
# Name: actual_x, dtype: int64

# %%
22/(22+19)
# Out:
# 0.5365853658536586
